# %% [markdown]
# # Plotly Notebook:
# ###### The goal is to display the **MSE** and an animated graph of **prediction** with Plotly for each $k$.
# `pip install plotly`
#
# `conda install -c plotly plotly=5.13.1`
#
# `-m pip install statsmodels`

# %%
import pandas as pd

import numpy as np

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

import plotly.express as px

import seaborn as sns

# %% [markdown]
# Open the **.xlsx**

# %%
file = "SURF_data.xlsx"
data = pd.read_excel(file , decimal = ',')
data.drop('refroid', axis = 1, inplace=True)

# %%
data.head(3)
# Out:
#    compacité  Surface    mur    toit  hauteur  orientation  vitrage  or_vitre  \
# 0       0.98    514.5  294.0  110.25      7.0            2      0.0         0
# 1       0.98    514.5  294.0  110.25      7.0            3      0.0         0
# 2       0.98    514.5  294.0  110.25      7.0            4      0.0         0
#
#    chauff
# 0   15.55
# 1   15.55
# 2   15.55

# %% [markdown]
# #### Standardisation et One Hot encoding

# %%
var_quanti = ['compacité', 'Surface', 'mur', 'toit', 'hauteur', 'vitrage', 'chauff']
data[var_quanti] = StandardScaler().fit_transform(data[var_quanti])
#
var_quali = ['orientation','or_vitre']
data_quali_encoded = pd.get_dummies(data[var_quali])
#
df = pd.concat([data[var_quanti], data_quali_encoded], axis = 1)
#
X_num = df.drop('chauff', axis=1)
Y_num = df['chauff']

# %% [markdown]
# #### **KPPV** et regression :
# (70% TRAIN - 30% VALIDATION)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_num, Y_num, test_size= 0.30)

# %%
def regression_simple(X_train : pd.Series, X_test : pd.Series, Y_train : pd.Series, k_neighbors : int = 20) -> np.array([]):
	KNN_Reg = KNeighborsRegressor(n_neighbors=k_neighbors)
	KNN_Reg.fit(X_train, Y_train)
	Y_pred = KNN_Reg.predict(X_test)

	return Y_pred

# %%
def MSE(Y_pred : pd.Series, Y_test : pd.Series) -> float:
	return np.sum(np.power(Y_pred - Y_test, 2)).sum()

# %% [markdown]
# ***

# %%
Y_pred = regression_simple(X_train, X_test, Y_train)
df_result_scatter = pd.DataFrame({'obs' : Y_test, 'pred': Y_pred})

# %%
px.scatter(df_result_scatter,title="estimation Y par rapport à la valeur réel",template="plotly_dark")
# Out:
# <div>                            <div id="be0311f0-fdea-4de7-b2f8-d0961219324a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be0311f0-fdea-4de7-b2f8-d0961219324a")) {                    Plotly.newPlot(                        "be0311f0-fdea-4de7-b2f8-d0961219324a",                        [{"hovertemplate":"variable=obs<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"obs","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"obs","orientation":"v","showlegend":true,"x":[234,347,544,316,78,5,408,551,517,93,117,648,132,398,576,525,184,759,430,235,334,470,31,21,28,567,136,427,392,154,105,304,506,565,11,376,204,477,501,379,248,421,336,519,110,34,81,447,729,256,450,306,206,257,516,344,756,250,89,48,476,549,100,164,715,556,581,578,634,588,452,367,740,750,150,758,225,364,261,719,101,691,297,320,665,764,146,226,605,199,734,247,176,399,363,290,541,205,571,103,382,593,725,568,45,710,13,488,716,532,233,400,149
# Chaque point 'obs' à un point 'pred' relié : *ctd* qu'ils sont sur la <u>même abscisse, mais ont des ordonnées différentes dû à l'erreur d'estimation<u>.

# %% [markdown]
# ***
# ### Création du DataFrame $\forall k$:
# Le df doit contenir la valeur du **MSE** et la **régression** pour chaque $k$.
# Le but est de vor l'évolution des predictions et de leurs précisions en fonction du nombre d'itérations $k$ : [exemple](#Plotly-:-Gapminder-example)

# %% [markdown]
# ##### Faire un df pandas avec comme colonne :
# 1. index
# 2. $k_{n}$
# 3. MSE
# 4. valeur réelle
# 5. valeur prédite

# %%
def regression_k(kmax : int = 80) -> pd.DataFrame :
	"""
	regression_k renvoie une Série avec toutes les erreurs pour chaque k et renvoie une liste de np.array() qui contiennent les approximations de Y avec regression_simple
	:param kmax: le nombre d'itérations
	:return: mse, res
	"""
	# Création du dataframe
	columns_mane	= ['k_n', 'MSE', 'val_obs_test', 'val_pred']
	types 			= {'k_n': int, 'MSE': float, 'val_obs_test': float,'val_pred' : float}


	df = pd.DataFrame(columns=columns_mane) #, dtype=types, index=range(1, kmax+1))

	for k in range(1, kmax+1):
		mse = MSE(Y_pred, Y_test)
		prediction = regression_simple(X_train, X_test, Y_train, k)

		df.loc[k] = [k, mse, Y_test, prediction]

	return df

# %%
test = regression_k()
test
# Out:
#     k_n       MSE                                       val_obs_test  \
# 1     1  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 2     2  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 3     3  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 4     4  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 5     5  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# ..  ...       ...                                                ...
# 76   76  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 77   77  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 78   78  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 79   79  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
# 80   80  20.25621  234   -0.692924
# 347    0.604227
# 544    1.89344...
#
#                                              val_pred
# 1   [-1.0886151502170536, 0.26109684566797015, 0.6...
# 2   [-1.0058076912483545, 0.5943100937336335, 1.34...
# 3   [-0.9081246408481526, 0.6062105668788358, 1.53...
# 4   [-0.8592831156480516, 0.627284321406798, 1.266...
# 5   [-0.8014170649795055, 0.5623771574606741, 1.20...
# ..                                                ...
# 76  [-0.9001648945558574, 0.8780685246717569, 1.18...
# 77  [-0.8938157386140405, 0.8792388463216309, 1.19...
# 78  [-0.8951434623425422, 0.8709198092753221, 1.18...
# 79  [-0.8963999130869513, 0.8723518444647358, 1.18...
# 80  [-0.8973646297126987, 0.8836155544239777, 1.19...
#
# [80 rows x 4 columns]

# %% [markdown]
# ***
# ### Plots :
# Linegraph de l'erreur en fonction du $k$

# %%
import plotly.graph_objs as go

df = regression_k()

# Create the figure object
fig = go.Figure()

# Add a trace for the actual values
fig.add_trace(go.Scatter(x=df['k_n'], y=df['val_obs_test'], name='Actual'))

# Add a trace for the predicted values
fig.add_trace(go.Scatter(x=df['k_n'], y=df['val_pred'], name='Predicted'))

# Set the layout properties
fig.update_layout(
    title='K-Nearest Neighbors Regression',
    xaxis_title='Number of Neighbors (k)',
    yaxis_title='Value',
    xaxis=dict(range=[1, 80], autorange=False),
    yaxis=dict(range=[0, 100], autorange=False),
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, dict(frame=dict(duration=500, redraw=True), fromcurrent=True)]
        ), dict(
            label='Pause',
            method='animate',
            args=[[None], dict(frame=dict(duration=0, redraw=False), mode='immediate', transition=dict(duration=0))]
        )]
    )]
)

# Create the frames for the animation
frames = [go.Frame(data=[go.Scatter(x=df['k_n'][:i], y=df['val_obs_test'][:i], name='Actual'),
                         go.Scatter(x=df['k_n'][:i], y=df['val_pred'][:i], name='Predicted')]) for i in range(1, len(df))]

# Add the frames to the figure
fig.frames = frames

# Add a slider to control the animation
fig.update_layout(
    updatemenus=[dict(
        type='buttons',
        showactive=False,
        buttons=[dict(
            label='Play',
            method='animate',
            args=[None, dict(frame=dict(duration=500, redraw=True), fromcurrent=True)]
        ), dict(
            label='Pause',
            method='animate',
            args=[[None], dict(frame=dict(duration=0, redraw=False), mode='immediate', transition=dict(duration=0))]
        )]
    ), dict(
        type='slider',
        active=len(df)-1,
        steps=[dict(
            label=str(k),
            method='animate',
            args=[[f.name] for f in fig.frames[:i+1]]
        ) for i, k in enumerate(df['k_n'])]
    )]
)

# Show the figure
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 44
#      41 fig.frames = frames
#      43 # Add a slider to control the animation
# ---> 44 fig.update_layout(
#      45     updatemenus=[dict(
#      46         type='buttons',
#      47         showactive=False,
#      48         buttons=[dict(
#      49             label='Play',
#      50             method='animate',
#      51             args=[None, dict(frame=dict(duration=500, redraw=True), fromcurrent=True)]
#      52         ), dict(
#      53             label='Pause',
#      54             method='animate',
#      55             args=[[None], dict(frame=dict(duration=0, redraw=False), mode='immediate', transition=dict(duration=0))]
#      56         )]
#      57     ), dict(
#      58         type='slider',
#      59         active=len(df)-1,
#      60         steps=[dict(
#      61             label=str(k),
#      62             method='animate',
#      63             args=[[f.name] for f in fig.frames[:i+1]]
#      64         ) for i, k in enumerate(df['k_n'])]
#      65     )]
#      66 )
#      68 # Show the figure
#      69 fig.show()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\graph_objs\_figure.py:775, in Figure.update_layout(self, dict1, overwrite, **kwargs)
#     749 def update_layout(self, dict1=None, overwrite=False, **kwargs) -> "Figure":
#     750     """
#     751
#     752     Update the properties of the figure's layout with a dict and/or with
#    (...)
#     773
#     774     """
# --> 775     return super(Figure, self).update_layout(dict1, overwrite, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:1393, in BaseFigure.update_layout(self, dict1, overwrite, **kwargs)
#    1369 def update_layout(self, dict1=None, overwrite=False, **kwargs):
#    1370     """
#    1371     Update the properties of the figure's layout with a dict and/or with
#    1372     keyword arguments.
#    (...)
#    1391         The Figure object that the update_layout method was called on
#    1392     """
# -> 1393     self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1394     return self
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5114, in BasePlotlyType.update(self, dict1, overwrite, **kwargs)
#    5112     with self.figure.batch_update():
#    5113         BaseFigure._perform_update(self, dict1, overwrite=overwrite)
# -> 5114         BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5115 else:
#    5116     BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:3912, in BaseFigure._perform_update(plotly_obj, update_obj, overwrite)
#    3907     # If update tuple is longer that current tuple, append the
#    3908     # extra elements to the end
#    3909     if isinstance(val, (list, tuple)) and len(val) > len(
#    3910         plotly_obj[key]
#    3911     ):
# -> 3912         plotly_obj[key] = plotly_obj[key] + tuple(
#    3913             val[len(plotly_obj[key]) :]
#    3914         )
#    3915 else:
#    3916     # plotly_obj is an empty or uninitialized list for key
#    3917     # In this case we accept val as is
#    3918     plotly_obj[key] = val
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5853, in BaseLayoutType.__setitem__(self, prop, value)
#    5850 match = self._subplot_re_match(prop)
#    5851 if match is None:
#    5852     # Set as ordinary property
# -> 5853     super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5854 else:
#    5855     # Set as subplotid property
#    5856     self._set_subplotid_prop(prop, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:4847, in BasePlotlyType.__setitem__(self, prop, value)
#    4845 # ### Handle compound array property ###
#    4846 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
# -> 4847     self._set_array_prop(prop, value)
#    4849 # ### Handle simple property ###
#    4850 else:
#    4851     self._set_prop(prop, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5328, in BasePlotlyType._set_array_prop(self, prop, val)
#    5325 # Import value
#    5326 # ------------
#    5327 validator = self._get_validator(prop)
# -> 5328 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5330 # Save deep copies of current and new states
#    5331 # ------------------------------------------
#    5332 curr_val = self._compound_array_props.get(prop, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:2568, in CompoundArrayValidator.validate_coerce(self, v, skip_invalid)
#    2566     res.append(self.data_class(v_el))
#    2567 elif isinstance(v_el, dict):
# -> 2568     res.append(self.data_class(v_el, skip_invalid=skip_invalid))
#    2569 else:
#    2570     if skip_invalid:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\graph_objs\layout\_updatemenu.py:877, in Updatemenu.__init__(self, arg, active, bgcolor, bordercolor, borderwidth, buttons, buttondefaults, direction, font, name, pad, showactive, templateitemname, type, visible, x, xanchor, y, yanchor, **kwargs)
#     875 _v = type if type is not None else _v
#     876 if _v is not None:
# --> 877     self["type"] = _v
#     878 _v = arg.pop("visible", None)
#     879 _v = visible if visible is not None else _v
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:4851, in BasePlotlyType.__setitem__(self, prop, value)
#    4847         self._set_array_prop(prop, value)
#    4849     # ### Handle simple property ###
#    4850     else:
# -> 4851         self._set_prop(prop, value)
#    4852 else:
#    4853     # Make sure properties dict is initialized
#    4854     self._init_props()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5195, in BasePlotlyType._set_prop(self, prop, val)
#    5193         return
#    5194     else:
# -> 5195         raise err
#    5197 # val is None
#    5198 # -----------
#    5199 if val is None:
#    5200     # Check if we should send null update
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\plotly\basedatatypes.py:5190, in BasePlotlyType._set_prop(self, prop, val)
#    5187 validator = self._get_validator(prop)
#    5189 try:
# -> 5190     val = validator.validate_coerce(val)
#    5191 except ValueError as err:
#    5192     if self._skip_invalid:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:611, in EnumeratedValidator.validate_coerce(self, v)
#     609     v = self.perform_replacemenet(v)
#     610     if not self.in_values(v):
# --> 611         self.raise_invalid_val(v)
#     612 return v
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\_plotly_utils\basevalidators.py:288, in BaseValidator.raise_invalid_val(self, v, inds)
#     285             for i in inds:
#     286                 name += "[" + str(i) + "]"
# --> 288         raise ValueError(
#     289             """
#     290     Invalid value of type {typ} received for the '{name}' property of {pname}
#     291         Received value: {v}
#     292
#     293 {valid_clr_desc}""".format(
#     294                 name=name,
#     295                 pname=self.parent_name,
#     296                 typ=type_str(v),
#     297                 v=repr(v),
#     298                 valid_clr_desc=self.description(),
#     299             )
#     300         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'type' property of layout.updatemenu
#         Received value: 'slider'
#
#     The 'type' property is an enumeration that may be specified as:
#       - One of the following enumeration values:
#             ['dropdown', 'buttons']

# %% [markdown]
# <br/>
# <br/>
# <br/>
# <br/>
#
# ***
# ### Plotly : Gapminder example
# [plotly demo](https://plotly.com/python/animations/)
# ***

# %%
df = px.data.gapminder()
print("df.size \t : {}".format(df.size))
print("df.shape \t : {}".format(df.shape))
print("df.columns \t : {} ".format(df.columns.to_list()))
# Out:
# df.size 	 : 13632
# df.shape 	 : (1704, 8)
# df.columns 	 : ['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap', 'iso_alpha', 'iso_num']

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %%
df = px.data.gapminder()
px.scatter(df, x="gdpPercap", y="lifeExp", animation_frame="year",
           #animation_group="country",
           #size="pop",
           #color="continent", hover_name="country",
           log_x=True,
           size_max=55, range_x=[100,100000], range_y=[25,90]
           )
# Out:
# <div>                            <div id="268c17cd-993e-4855-aba3-0ad4a32e1018" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...

# %% [markdown]
# ***

# %% [markdown]
# # tests

# %%
nb_records = 3
nb_k = 8

pattern_k = [i for i in range(1, nb_k+1) for j in range(nb_records)]
k = np.repeat(pattern_k,1)

pattern_mse = [np.abs(np.random.randn(1)) for i in range(1, nb_k+1, nb_k) for j in range(nb_k)]
mse = np.repeat(pattern_mse,nb_records)


obs = np.sort(np.abs(np.random.randn(nb_records*nb_k)*10))
pred = np.abs(np.random.randn(nb_records*nb_k)*10)

data = {
	'k_n'	: k,
	'mse'	: mse,
	'obs'	: obs,
	'pred'	: pred
}

"""
print(k.shape)
print(mse.shape)
print(pred.shape)
print(obs.shape)
print(df_test.shape)
"""

df_test = pd.DataFrame(data)
df_test.head(200)
# Out:
#     k_n       mse        obs       pred
# 0     1  0.390154   0.192464   1.693597
# 1     1  0.390154   1.187800   4.737395
# 2     1  0.390154   1.448105  13.683579
# 3     2  1.173389   3.025048  12.469756
# 4     2  1.173389   3.109643   0.073590
# 5     2  1.173389   3.315368  19.935769
# 6     3  1.513044   3.415407  15.100026
# 7     3  1.513044   3.796096   5.833252
# 8     3  1.513044   5.295615  12.625375
# 9     4  1.017492   6.514429  19.640705
# 10    4  1.017492   6.516665  19.739610
# 11    4  1.017492   6.994092  10.399967
# 12    5  0.545495   9.687177   9.211734
# 13    5  0.545495  10.850034   7.420187
# 14    5  0.545495  10.853771  17.310656
# 15    6  0.408346  12.047963   7.941005
# 16    6  0.408346  12.335509  15.355883
# 17    6  0.408346  12.419440   8.489844
# 18    7  0.306398  12.470420   2.383661
# 19    7  0.306398  12.616536  16.045882
# 20    7  0.306398  14.396029  10.092559
# 21    8  0.865619  16.701694   1.094481
# 22    8  0.865619  18.698885  24.002239
# 23    8  0.865619  19.018289   6.485150

# %%
import pandas as pd
import plotly.express as px
import statsmodels as sm


px.scatter(df_test, x="obs", y="pred", animation_frame="k_n",
           #animation_group="mse",
           size="obs",
           color="mse", hover_name="mse",
           log_x=False,
           size_max=55,range_x=[0.1,30], range_y=[-0.5,30],
           trendline="ols"
           )
# Out:
# <div>                            <div id="085b42d1-c204-4b2b-b615-1e9ca9d6a7d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("085b42d1-c204-4b2b-b615-1e9ca9d6a7d6")) {                    Plotly.newPlot(                        "085b42d1-c204-4b2b-b615-1e9ca9d6a7d6",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>k_n=1<br>obs=%{marker.size}<br>pred=%{y}<br>mse=%{marker.color}<extra></extra>","hovertext":[1.4345912372057523,1.4345912372057523,1.4345912372057523,1.4345912372057523,1.4345912372057523,1.4345912372